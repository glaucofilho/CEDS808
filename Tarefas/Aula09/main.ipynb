# %% [markdown]
# # <a id="inicio"></a> Exercícios Métricas de avaliação e seleção de hiper parâmetro
#
# -----
#
# ### **Autor:** Glauco Lauria Marques Filho
#
# -----

# %% [markdown]
# # <a id="resumo"></a> Resumo

# %% [markdown]
# #### Este arquivo contém a resolução dos exercícios da Aula 9 do curso CEDS-808: Aprendizado de Máquina.

# %% [markdown]
# # <a id="sumario"></a> Sumário

# %% [markdown]
# * [Início](#inicio)
# * [Resumo](#resumo)
# * [Sumário](#sumario)
# * [Importação de Requisitos](#requisitos)
#
# - 1.a [Dataset Aggregation](#dataset_1_a)
# - 1.a.I [Dataset Aggregation - K-means](#dataset_1_a_I)
# - 1.a.II [Dataset Aggregation - Average Linkage](#dataset_1_a_II)
# - 1.a.III [Dataset Aggregation - DBSCAN](#dataset_1_a_III)
#
# <br>
#
# - 1.b [Dataset D31](#dataset_1_b)
# - 1.b.I [Dataset D31 - K-means](#dataset_1_b_I)
# - 1.b.II [Dataset D31 - Average Linkage](#dataset_1_b_II)
# - 1.b.III [Dataset D31 - DBSCAN](#dataset_1_b_III)
#
# <br>
#
# - 1.c [Dataset Pathbased](#dataset_1_c)
# - 1.c.I [Dataset Pathbased - K-means](#dataset_1_c_I)
# - 1.c.II [Dataset Pathbased - Average Linkage](#dataset_1_c_II)
# - 1.c.III [Dataset Pathbased - DBSCAN](#dataset_1_c_III)
#
# <br>
#
# - 1.d [Dataset Flame](#dataset_1_d)
# - 1.d.I [Dataset Flame - K-means](#dataset_1_d_I)
# - 1.d.II [Dataset Flame - Average Linkage](#dataset_1_d_II)
# - 1.d.III [Dataset Flame - DBSCAN](#dataset_1_d_III)

# %% [markdown]
# # <a id="requisitos"></a> Importação de Requisitos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.metrics import adjusted_rand_score, jaccard_score, fowlkes_mallows_score
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# %%
def dunn_index(X, labels, cluster_centers):
    max_intra_cluster_distances = np.zeros(len(np.unique(labels)))
    for cluster_label in np.unique(labels):
        cluster_points = X[labels == cluster_label]
        max_intra_cluster_distances[cluster_label] = np.max(pairwise_distances(cluster_points))

    inter_cluster_distances = pairwise_distances(cluster_centers)
    min_inter_cluster_distance = np.min(inter_cluster_distances[np.nonzero(inter_cluster_distances)])

    return min_inter_cluster_distance / np.max(max_intra_cluster_distances)

# %% [markdown]
# # <a id="dataset_1"></a> 1.a. Dataset Aggregation

# %%
df = pd.read_csv("aggregation.csv", sep=";", names=["x1","x2","y"])
X = df.drop("y", axis=1)
Y = df["y"]

# %% [markdown]
# # <a id="dataset_1_a_I"></a> 1.a.I. Dataset Aggregation - K-Means

# %%
models_score = {
    "Silouette Score": [0,""],
    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 11):

    # #######
    model = KMeans(n_clusters=k)
    model_text = f"K-Means com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    dunn_value = dunn_index(X, labels, model.cluster_centers_)
    if dunn_value > models_score["Dunn Score"][0]:
        models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# K-Means com k=2
# Silouette Score = 0.4560
# Dunn Score = 0.6354
# Calinski-Harabasz Score = 704.6910
# Davies-Bouldin Score = 0.8936
# Jaccard Score = 0.0057
# Rand Score = 0.3453
# Folkes e Mallows Score = 0.6108
#
#
# K-Means com k=3
# Silouette Score = 0.5234
# Dunn Score = 0.6553
# Calinski-Harabasz Score = 1053.6642
# Davies-Bouldin Score = 0.6669
# Jaccard Score = 0.1807
# Rand Score = 0.6744
# Folkes e Mallows Score = 0.7829
#
#
# K-Means com k=4
# Silouette Score = 0.5221
# Dunn Score = 0.6912
# Calinski-Harabasz Score = 1169.3026
# Davies-Bouldin Score = 0.6149
# Jaccard Score = 0.0034
# Rand Score = 0.7562
# Folkes e Mallows Score = 0.8259
#
#
# K-Means com k=5
# Silouette Score = 0.4987
# Dunn Score = 0.5457
# Calinski-Harabasz Score = 1326.0476
# Davies-Bouldin Score = 0.7042
# Jaccard Score = 0.2576
# Rand Score = 0.7350
# Folkes e Mallows Score = 0.7914
#
#
# K-Means com k=6
# Silouette Score = 0.4665
# Dunn Score = 0.3972
# Calinski-Harabasz Score = 1178.2734
# Davies-Bouldin Score = 0.7971
# Jaccard Score = 0.2548
# Rand Score = 0.6917
# Folkes e Mallows Score = 0.7555
#
#
# K-Means com k=7
# Silouette Score = 0.4811
# Dunn Score = 0.4490
# Calinski-Harabasz Score = 1396.1716
# Davies-Bouldin Score = 0.7340
# Jaccard Score = 0.2132
# Rand Score = 0.7633
# Folkes e Mallows Score = 0.8167
#
#
# K-Means com k=8
# Silouette Score = 0.4693
# Dunn Score = 0.4455
# Calinski-Harabasz Score = 1349.9186
# Davies-Bouldin Score = 0.7998
# Jaccard Score = 0.0401
# Rand Score = 0.7022
# Folkes e Mallows Score = 0.7686
#
#
# K-Means com k=9
# Silouette Score = 0.4245
# Dunn Score = 0.4189
# Calinski-Harabasz Score = 1369.9382
# Davies-Bouldin Score = 0.8602
# Jaccard Score = 0.2437
# Rand Score = 0.6248
# Folkes e Mallows Score = 0.7118
#
#
# K-Means com k=10
# Silouette Score = 0.4393
# Dunn Score = 0.4189
# Calinski-Harabasz Score = 1424.3189
# Davies-Bouldin Score = 0.8024
# Jaccard Score = 0.1103
# Rand Score = 0.6233
# Folkes e Mallows Score = 0.7144

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.5234 - Best Model: K-Means com k=3
# Dunn Score = 0.6912 - Best Model: K-Means com k=4
# Calinski-Harabasz Score = 1424.3189 - Best Model: K-Means com k=10
# Davies-Bouldin Score = 0.8936 - Best Model: K-Means com k=2
# Jaccard Score = 0.2576 - Best Model: K-Means com k=5
# Rand Score = 0.7633 - Best Model: K-Means com k=7
# Folkes e Mallows Score = 0.8259 - Best Model: K-Means com k=4

# %% [markdown]
# # <a id="dataset_1_a_II"></a> 1.a.II. Dataset Aggregation - Average Linkage

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 11):

    # #######
    model = AgglomerativeClustering(n_clusters=k, linkage='average')
    model_text = f"Average Linkage com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    # dunn_value = dunn_index(X, labels, model.cluster_centers_)
    # if dunn_value > models_score["Dunn Score"][0]:
    #     models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        # + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# Average Linkage com k=2
# Silouette Score = 0.4533
# Calinski-Harabasz Score = 692.9809
# Davies-Bouldin Score = 0.9182
# Jaccard Score = 0.0093
# Rand Score = 0.3768
# Folkes e Mallows Score = 0.6312
#
#
# Average Linkage com k=3
# Silouette Score = 0.5124
# Calinski-Harabasz Score = 988.5203
# Davies-Bouldin Score = 0.6735
# Jaccard Score = 0.2157
# Rand Score = 0.6655
# Folkes e Mallows Score = 0.7793
#
#
# Average Linkage com k=4
# Silouette Score = 0.5220
# Calinski-Harabasz Score = 1141.6939
# Davies-Bouldin Score = 0.5968
# Jaccard Score = 0.3599
# Rand Score = 0.7864
# Folkes e Mallows Score = 0.8510
#
#
# Average Linkage com k=5
# Silouette Score = 0.5008
# Calinski-Harabasz Score = 1208.0022
# Davies-Bouldin Score = 0.6824
# Jaccard Score = 0.6916
# Rand Score = 0.9358
# Folkes e Mallows Score = 0.9516
#
#
# Average Linkage com k=6
# Silouette Score = 0.5124
# Calinski-Harabasz Score = 1306.1808
# Davies-Bouldin Score = 0.6132
# Jaccard Score = 0.3452
# Rand Score = 0.9891
# Folkes e Mallows Score = 0.9915
#
#
# Average Linkage com k=7
# Silouette Score = 0.4925
# Calinski-Harabasz Score = 1200.1715
# Davies-Bouldin Score = 0.5036
# Jaccard Score = 0.1294
# Rand Score = 1.0000
# Folkes e Mallows Score = 1.0000
#
#
# Average Linkage com k=8
# Silouette Score = 0.4580
# Calinski-Harabasz Score = 1104.3439
# Davies-Bouldin Score = 0.5729
# Jaccard Score = 0.1294
# Rand Score = 0.9723
# Folkes e Mallows Score = 0.9784
#
#
# Average Linkage com k=9
# Silouette Score = 0.4511
# Calinski-Harabasz Score = 1272.2391
# Davies-Bouldin Score = 0.6841
# Jaccard Score = 0.3211
# Rand Score = 0.7714
# Folkes e Mallows Score = 0.8264
#
#
# Average Linkage com k=10
# Silouette Score = 0.4491
# Calinski-Harabasz Score = 1288.1706
# Davies-Bouldin Score = 0.7227
# Jaccard Score = 0.1294
# Rand Score = 0.7126
# Folkes e Mallows Score = 0.7828

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.5220 - Best Model: Average Linkage com k=4
# Calinski-Harabasz Score = 1306.1808 - Best Model: Average Linkage com k=6
# Davies-Bouldin Score = 0.9182 - Best Model: Average Linkage com k=2
# Jaccard Score = 0.6916 - Best Model: Average Linkage com k=5
# Rand Score = 1.0000 - Best Model: Average Linkage com k=7
# Folkes e Mallows Score = 1.0000 - Best Model: Average Linkage com k=7

# %% [markdown]
# # <a id="dataset_1_a_III"></a> 1.a.III Dataset Aggregation - DBSCAN

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}
epsilon_values = [0.3, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]

for k in range(2, 11):

    # #######
    model = DBSCAN(eps=epsilon_values[k-2], min_samples=8)
    model_text = f'DBSCAN com eps={epsilon_values[k-2]} e min_samples=8'
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_
    try:
        silhouette_value = silhouette_score(X, labels)
        if silhouette_value > models_score["Silouette Score"][0]:
            models_score["Silouette Score"] = [silhouette_value, model_text]
        # dunn_value = dunn_index(X, labels, model.cluster_centers_)
        # if dunn_value > models_score["Dunn Score"][0]:
        #     models_score["Dunn Score"] = [dunn_value, model_text]
        ch_value = calinski_harabasz_score(X, labels)
        if ch_value > models_score["Calinski-Harabasz Score"][0]:
            models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
        db_value = davies_bouldin_score(X, labels)
        if db_value > models_score["Davies-Bouldin Score"][0]:
            models_score["Davies-Bouldin Score"] = [db_value, model_text]
        jaccard_value = jaccard_score(Y, labels, average='weighted')
        if jaccard_value > models_score["Jaccard Score"][0]:
            models_score["Jaccard Score"] = [jaccard_value, model_text]
        rand_value = adjusted_rand_score(Y, labels)
        if rand_value > models_score["Rand Score"][0]:
            models_score["Rand Score"] = [rand_value, model_text]
        fm_value = fowlkes_mallows_score(Y, labels)
        if fm_value > models_score["Folkes e Mallows Score"][0]:
            models_score["Folkes e Mallows Score"] = [fm_value, model_text]
    except:
       pass

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
     #   + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# DBSCAN com eps=0.3 e min_samples=8
# Silouette Score = 0.4491
# Calinski-Harabasz Score = 1288.1706
# Davies-Bouldin Score = 0.7227
# Jaccard Score = 0.1294
# Rand Score = 0.7126
# Folkes e Mallows Score = 0.7828
#
#
# DBSCAN com eps=0.5 e min_samples=8
# Silouette Score = 0.4491
# Calinski-Harabasz Score = 1288.1706
# Davies-Bouldin Score = 0.7227
# Jaccard Score = 0.1294
# Rand Score = 0.7126
# Folkes e Mallows Score = 0.7828
#
#
# DBSCAN com eps=1.0 e min_samples=8
# Silouette Score = -0.3123
# Calinski-Harabasz Score = 22.0591
# Davies-Bouldin Score = 1.1601
# Jaccard Score = 0.0305
# Rand Score = 0.0362
# Folkes e Mallows Score = 0.3230
#
#
# DBSCAN com eps=1.5 e min_samples=8
# Silouette Score = 0.4385
# Calinski-Harabasz Score = 1052.3234
# Davies-Bouldin Score = 0.6019
# Jaccard Score = 0.1270
# Rand Score = 0.9850
# Folkes e Mallows Score = 0.9882
#
#
# DBSCAN com eps=2.0 e min_samples=8
# Silouette Score = 0.4120
# Calinski-Harabasz Score = 754.2002
# Davies-Bouldin Score = 0.6249
# Jaccard Score = 0.0000
# Rand Score = 0.8089
# Folkes e Mallows Score = 0.8652
#
#
# DBSCAN com eps=2.5 e min_samples=8
# Silouette Score = 0.4120
# Calinski-Harabasz Score = 754.2002
# Davies-Bouldin Score = 0.6249
# Jaccard Score = 0.0000
# Rand Score = 0.8089
# Folkes e Mallows Score = 0.8652
#
#
# DBSCAN com eps=3.0 e min_samples=8
# Silouette Score = 0.4695
# Calinski-Harabasz Score = 860.9796
# Davies-Bouldin Score = 0.6386
# Jaccard Score = 0.0000
# Rand Score = 0.7338
# Folkes e Mallows Score = 0.8189
#
#
# DBSCAN com eps=3.5 e min_samples=8
# Silouette Score = 0.4695
# Calinski-Harabasz Score = 860.9796
# Davies-Bouldin Score = 0.6386
# Jaccard Score = 0.0000
# Rand Score = 0.7338
# Folkes e Mallows Score = 0.8189
#
#
# DBSCAN com eps=4.0 e min_samples=8
# Silouette Score = 0.2856
# Calinski-Harabasz Score = 425.0562
# Davies-Bouldin Score = 0.8184
# Jaccard Score = 0.0000
# Rand Score = 0.4198
# Folkes e Mallows Score = 0.6517

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.4695 - Best Model: DBSCAN com eps=3.0 e min_samples=8
# Calinski-Harabasz Score = 1052.3234 - Best Model: DBSCAN com eps=1.5 e min_samples=8
# Davies-Bouldin Score = 1.1601 - Best Model: DBSCAN com eps=1.0 e min_samples=8
# Jaccard Score = 0.1270 - Best Model: DBSCAN com eps=1.5 e min_samples=8
# Rand Score = 0.9850 - Best Model: DBSCAN com eps=1.5 e min_samples=8
# Folkes e Mallows Score = 0.9882 - Best Model: DBSCAN com eps=1.5 e min_samples=8

# %% [markdown]
# ---

# %% [markdown]
# # <a id="dataset_1_b"></a> 1.b. Dataset D31

# %%
df = pd.read_csv("d31.csv", sep=";", names=["x1","x2","y"])
X = df.drop("y", axis=1)
Y = df["y"]

# %% [markdown]
# # <a id="dataset_1_b_I"></a> 1.b.I. Dataset D31 - K-Means

# %%
models_score = {
    "Silouette Score": [0,""],
    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 34):

    # #######
    model = KMeans(n_clusters=k)
    model_text = f"K-Means com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    dunn_value = dunn_index(X, labels, model.cluster_centers_)
    if dunn_value > models_score["Dunn Score"][0]:
        models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# K-Means com k=2
# Silouette Score = 0.3943
# Dunn Score = 0.4926
# Calinski-Harabasz Score = 2292.8938
# Davies-Bouldin Score = 1.0661
# Jaccard Score = 0.0021
# Rand Score = 0.0593
# Folkes e Mallows Score = 0.2437
#
#
# K-Means com k=3
# Silouette Score = 0.4207
# Dunn Score = 0.5632
# Calinski-Harabasz Score = 2890.5771
# Davies-Bouldin Score = 0.7954
# Jaccard Score = 0.0031
# Rand Score = 0.1132
# Folkes e Mallows Score = 0.2956
#
#
# K-Means com k=4
# Silouette Score = 0.4286
# Dunn Score = 0.6614
# Calinski-Harabasz Score = 3370.7142
# Davies-Bouldin Score = 0.7911
# Jaccard Score = 0.0061
# Rand Score = 0.1640
# Folkes e Mallows Score = 0.3345
# K-Means com k=5
# Silouette Score = 0.4120
# Dunn Score = 0.4920
# Calinski-Harabasz Score = 3217.5187
# Davies-Bouldin Score = 0.8217
# Jaccard Score = 0.0067
# Rand Score = 0.2052
# Folkes e Mallows Score = 0.3681
#
#
# K-Means com k=6
# Silouette Score = 0.4217
# Dunn Score = 0.5084
# Calinski-Harabasz Score = 3420.6234
# Davies-Bouldin Score = 0.8114
# Jaccard Score = 0.0067
# Rand Score = 0.2524
# Folkes e Mallows Score = 0.4058
#
#
# K-Means com k=7
# Silouette Score = 0.4246
# Dunn Score = 0.6224
# Calinski-Harabasz Score = 3675.6683
# Davies-Bouldin Score = 0.8305
# Jaccard Score = 0.0000
# Rand Score = 0.3049
# Folkes e Mallows Score = 0.4425
#
#
# K-Means com k=8
# Silouette Score = 0.4201
# Dunn Score = 0.5638
# Calinski-Harabasz Score = 3564.6539
# Davies-Bouldin Score = 0.8033
# Jaccard Score = 0.0000
# Rand Score = 0.3418
# Folkes e Mallows Score = 0.4693
#
#
# K-Means com k=9
# Silouette Score = 0.4512
# Dunn Score = 0.5590
# Calinski-Harabasz Score = 3742.6215
# Davies-Bouldin Score = 0.7377
# Jaccard Score = 0.0152
# Rand Score = 0.3546
# Folkes e Mallows Score = 0.4755
#
#
# K-Means com k=10
# Silouette Score = 0.4229
# Dunn Score = 0.5107
# Calinski-Harabasz Score = 3729.0815
# Davies-Bouldin Score = 0.8060
# Jaccard Score = 0.0000
# Rand Score = 0.4071
# Folkes e Mallows Score = 0.5113
#
#
# K-Means com k=11
# Silouette Score = 0.4450
# Dunn Score = 0.5385
# Calinski-Harabasz Score = 3839.7241
# Davies-Bouldin Score = 0.7648
# Jaccard Score = 0.0268
# Rand Score = 0.4481
# Folkes e Mallows Score = 0.5450
#
#
# K-Means com k=12
# Silouette Score = 0.4624
# Dunn Score = 0.4517
# Calinski-Harabasz Score = 3894.4213
# Davies-Bouldin Score = 0.7506
# Jaccard Score = 0.0211
# Rand Score = 0.4570
# Folkes e Mallows Score = 0.5526
#
#
# K-Means com k=13
# Silouette Score = 0.4585
# Dunn Score = 0.6026
# Calinski-Harabasz Score = 4163.8790
# Davies-Bouldin Score = 0.7356
# Jaccard Score = 0.0000
# Rand Score = 0.4950
# Folkes e Mallows Score = 0.5786
#
#
# K-Means com k=14
# Silouette Score = 0.4528
# Dunn Score = 0.4323
# Calinski-Harabasz Score = 4092.4158
# Davies-Bouldin Score = 0.7593
# Jaccard Score = 0.0006
# Rand Score = 0.5149
# Folkes e Mallows Score = 0.5899
#
#
# K-Means com k=15
# Silouette Score = 0.4653
# Dunn Score = 0.4529
# Calinski-Harabasz Score = 4434.1020
# Davies-Bouldin Score = 0.7268
# Jaccard Score = 0.0000
# Rand Score = 0.5395
# Folkes e Mallows Score = 0.6079
#
#
# K-Means com k=16
# Silouette Score = 0.4725
# Dunn Score = 0.4837
# Calinski-Harabasz Score = 4648.3226
# Davies-Bouldin Score = 0.7041
# Jaccard Score = 0.0001
# Rand Score = 0.5695
# Folkes e Mallows Score = 0.6294
#
#
# K-Means com k=17
# Silouette Score = 0.4875
# Dunn Score = 0.5145
# Calinski-Harabasz Score = 4968.2059
# Davies-Bouldin Score = 0.6351
# Jaccard Score = 0.0225
# Rand Score = 0.5771
# Folkes e Mallows Score = 0.6322
#
#
# K-Means com k=18
# Silouette Score = 0.5016
# Dunn Score = 0.4375
# Calinski-Harabasz Score = 5199.3638
# Davies-Bouldin Score = 0.6476
# Jaccard Score = 0.0017
# Rand Score = 0.6199
# Folkes e Mallows Score = 0.6685
#
#
# K-Means com k=19
# Silouette Score = 0.5004
# Dunn Score = 0.5331
# Calinski-Harabasz Score = 5244.8447
# Davies-Bouldin Score = 0.6206
# Jaccard Score = 0.0000
# Rand Score = 0.6251
# Folkes e Mallows Score = 0.6700
#
#
# K-Means com k=20
# Silouette Score = 0.4925
# Dunn Score = 0.4116
# Calinski-Harabasz Score = 5217.3195
# Davies-Bouldin Score = 0.6478
# Jaccard Score = 0.0330
# Rand Score = 0.6437
# Folkes e Mallows Score = 0.6809
#
#
# K-Means com k=21
# Silouette Score = 0.5134
# Dunn Score = 0.4405
# Calinski-Harabasz Score = 5568.9630
# Davies-Bouldin Score = 0.6005
# Jaccard Score = 0.0149
# Rand Score = 0.6802
# Folkes e Mallows Score = 0.7157
#
#
# K-Means com k=22
# Silouette Score = 0.4990
# Dunn Score = 0.4377
# Calinski-Harabasz Score = 5675.7904
# Davies-Bouldin Score = 0.6439
# Jaccard Score = 0.0001
# Rand Score = 0.6768
# Folkes e Mallows Score = 0.7054
#
#
# K-Means com k=23
# Silouette Score = 0.4940
# Dunn Score = 0.4096
# Calinski-Harabasz Score = 5572.6499
# Davies-Bouldin Score = 0.6873
# Jaccard Score = 0.0479
# Rand Score = 0.7202
# Folkes e Mallows Score = 0.7436
#
#
# K-Means com k=24
# Silouette Score = 0.5108
# Dunn Score = 0.4448
# Calinski-Harabasz Score = 5996.6204
# Davies-Bouldin Score = 0.6121
# Jaccard Score = 0.0610
# Rand Score = 0.7336
# Folkes e Mallows Score = 0.7550
#
#
# K-Means com k=25
# Silouette Score = 0.5189
# Dunn Score = 0.4446
# Calinski-Harabasz Score = 6174.9079
# Davies-Bouldin Score = 0.6322
# Jaccard Score = 0.0001
# Rand Score = 0.7666
# Folkes e Mallows Score = 0.7826
#
#
# K-Means com k=26
# Silouette Score = 0.5268
# Dunn Score = 0.4589
# Calinski-Harabasz Score = 6617.8209
# Davies-Bouldin Score = 0.6091
# Jaccard Score = 0.0000
# Rand Score = 0.7852
# Folkes e Mallows Score = 0.7987
#
#
# K-Means com k=27
# Silouette Score = 0.5419
# Dunn Score = 0.5065
# Calinski-Harabasz Score = 6831.0098
# Davies-Bouldin Score = 0.5696
# Jaccard Score = 0.0000
# Rand Score = 0.8187
# Folkes e Mallows Score = 0.8307
#
#
# K-Means com k=28
# Silouette Score = 0.5375
# Dunn Score = 0.5016
# Calinski-Harabasz Score = 7304.3519
# Davies-Bouldin Score = 0.6079
# Jaccard Score = 0.0583
# Rand Score = 0.8392
# Folkes e Mallows Score = 0.8464
#
#
# K-Means com k=29
# Silouette Score = 0.5501
# Dunn Score = 0.4991
# Calinski-Harabasz Score = 7777.7107
# Davies-Bouldin Score = 0.5857
# Jaccard Score = 0.0296
# Rand Score = 0.8726
# Folkes e Mallows Score = 0.8777
#
#
# K-Means com k=30
# Silouette Score = 0.5354
# Dunn Score = 0.2366
# Calinski-Harabasz Score = 7322.7836
# Davies-Bouldin Score = 0.6263
# Jaccard Score = 0.0006
# Rand Score = 0.8724
# Folkes e Mallows Score = 0.8773
#
#
# K-Means com k=31
# Silouette Score = 0.5356
# Dunn Score = 0.2389
# Calinski-Harabasz Score = 7288.4975
# Davies-Bouldin Score = 0.6363
# Jaccard Score = 0.0002
# Rand Score = 0.8678
# Folkes e Mallows Score = 0.8727
#
#
# K-Means com k=32
# Silouette Score = 0.5634
# Dunn Score = 0.2875
# Calinski-Harabasz Score = 8984.9337
# Davies-Bouldin Score = 0.5801
# Jaccard Score = 0.0310
# Rand Score = 0.9456
# Folkes e Mallows Score = 0.9474
#
#
# K-Means com k=33
# Silouette Score = 0.5514
# Dunn Score = 0.2071
# Calinski-Harabasz Score = 8773.4699
# Davies-Bouldin Score = 0.6320
# Jaccard Score = 0.0002
# Rand Score = 0.9363
# Folkes e Mallows Score = 0.9385

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.5634 - Best Model: K-Means com k=32
# Dunn Score = 0.6614 - Best Model: K-Means com k=4
# Calinski-Harabasz Score = 8984.9337 - Best Model: K-Means com k=32
# Davies-Bouldin Score = 1.0661 - Best Model: K-Means com k=2
# Jaccard Score = 0.0610 - Best Model: K-Means com k=24
# Rand Score = 0.9456 - Best Model: K-Means com k=32
# Folkes e Mallows Score = 0.9474 - Best Model: K-Means com k=32

# %% [markdown]
# # <a id="dataset_1_b_II"></a> 1.b.II. Dataset D31 - Average Linkage

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 34):

    # #######
    model = AgglomerativeClustering(n_clusters=k, linkage='average')
    model_text = f"Average Linkage com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    # dunn_value = dunn_index(X, labels, model.cluster_centers_)
    # if dunn_value > models_score["Dunn Score"][0]:
    #     models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        # + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# Average Linkage com k=2
# Silouette Score = 0.3737
# Calinski-Harabasz Score = 1985.2568
# Davies-Bouldin Score = 1.1500
# Jaccard Score = 0.0000
# Rand Score = 0.0637
# Folkes e Mallows Score = 0.2525
#
#
# Average Linkage com k=3
# Silouette Score = 0.3911
# Calinski-Harabasz Score = 2403.6033
# Davies-Bouldin Score = 0.8052
# Jaccard Score = 0.0036
# Rand Score = 0.0987
# Folkes e Mallows Score = 0.2866
#
#
# Average Linkage com k=4
# Silouette Score = 0.3855
# Calinski-Harabasz Score = 2734.8714
# Davies-Bouldin Score = 0.8793
# Jaccard Score = 0.0089
# Rand Score = 0.1688
# Folkes e Mallows Score = 0.3476
#
#
# Average Linkage com k=5
# Silouette Score = 0.3658
# Calinski-Harabasz Score = 2350.4588
# Davies-Bouldin Score = 0.8332
# Jaccard Score = 0.0000
# Rand Score = 0.1848
# Folkes e Mallows Score = 0.3607
#
#
# Average Linkage com k=6
# Silouette Score = 0.3614
# Calinski-Harabasz Score = 2557.7393
# Davies-Bouldin Score = 0.8479
# Jaccard Score = 0.0000
# Rand Score = 0.2285
# Folkes e Mallows Score = 0.3951
#
#
# Average Linkage com k=7
# Silouette Score = 0.3842
# Calinski-Harabasz Score = 2727.2450
# Davies-Bouldin Score = 0.7330
# Jaccard Score = 0.0000
# Rand Score = 0.2544
# Folkes e Mallows Score = 0.4151
#
#
# Average Linkage com k=8
# Silouette Score = 0.4009
# Calinski-Harabasz Score = 3029.0940
# Davies-Bouldin Score = 0.6943
# Jaccard Score = 0.0001
# Rand Score = 0.2843
# Folkes e Mallows Score = 0.4373
#
#
# Average Linkage com k=9
# Silouette Score = 0.4476
# Calinski-Harabasz Score = 3578.1031
# Davies-Bouldin Score = 0.7491
# Jaccard Score = 0.0064
# Rand Score = 0.3757
# Folkes e Mallows Score = 0.5037
#
#
# Average Linkage com k=10
# Silouette Score = 0.4437
# Calinski-Harabasz Score = 3552.7970
# Davies-Bouldin Score = 0.7104
# Jaccard Score = 0.0001
# Rand Score = 0.3940
# Folkes e Mallows Score = 0.5170
#
#
# Average Linkage com k=11
# Silouette Score = 0.4529
# Calinski-Harabasz Score = 3720.5986
# Davies-Bouldin Score = 0.6709
# Jaccard Score = 0.0000
# Rand Score = 0.4218
# Folkes e Mallows Score = 0.5370
#
#
# Average Linkage com k=12
# Silouette Score = 0.4514
# Calinski-Harabasz Score = 3731.5839
# Davies-Bouldin Score = 0.6692
# Jaccard Score = 0.0000
# Rand Score = 0.4359
# Folkes e Mallows Score = 0.5469
#
#
# Average Linkage com k=13
# Silouette Score = 0.4772
# Calinski-Harabasz Score = 3944.9261
# Davies-Bouldin Score = 0.6766
# Jaccard Score = 0.0000
# Rand Score = 0.4832
# Folkes e Mallows Score = 0.5807
#
#
# Average Linkage com k=14
# Silouette Score = 0.4664
# Calinski-Harabasz Score = 4203.9549
# Davies-Bouldin Score = 0.7362
# Jaccard Score = 0.0261
# Rand Score = 0.5406
# Folkes e Mallows Score = 0.6217
#
#
# Average Linkage com k=15
# Silouette Score = 0.4694
# Calinski-Harabasz Score = 4391.9657
# Davies-Bouldin Score = 0.6999
# Jaccard Score = 0.0261
# Rand Score = 0.5615
# Folkes e Mallows Score = 0.6361
#
#
# Average Linkage com k=16
# Silouette Score = 0.4717
# Calinski-Harabasz Score = 4574.9611
# Davies-Bouldin Score = 0.6738
# Jaccard Score = 0.0002
# Rand Score = 0.5840
# Folkes e Mallows Score = 0.6520
#
#
# Average Linkage com k=17
# Silouette Score = 0.4764
# Calinski-Harabasz Score = 4791.8933
# Davies-Bouldin Score = 0.6713
# Jaccard Score = 0.0165
# Rand Score = 0.6103
# Folkes e Mallows Score = 0.6709
#
#
# Average Linkage com k=18
# Silouette Score = 0.4825
# Calinski-Harabasz Score = 4920.9479
# Davies-Bouldin Score = 0.6117
# Jaccard Score = 0.0165
# Rand Score = 0.6236
# Folkes e Mallows Score = 0.6808
#
#
# Average Linkage com k=19
# Silouette Score = 0.4945
# Calinski-Harabasz Score = 5103.4524
# Davies-Bouldin Score = 0.6145
# Jaccard Score = 0.0315
# Rand Score = 0.6511
# Folkes e Mallows Score = 0.7009
#
#
# Average Linkage com k=20
# Silouette Score = 0.5061
# Calinski-Harabasz Score = 5234.1152
# Davies-Bouldin Score = 0.6047
# Jaccard Score = 0.0626
# Rand Score = 0.6668
# Folkes e Mallows Score = 0.7126
#
#
# Average Linkage com k=21
# Silouette Score = 0.5075
# Calinski-Harabasz Score = 5351.0712
# Davies-Bouldin Score = 0.6273
# Jaccard Score = 0.0626
# Rand Score = 0.7008
# Folkes e Mallows Score = 0.7386
#
#
# Average Linkage com k=22
# Silouette Score = 0.5122
# Calinski-Harabasz Score = 5497.3388
# Davies-Bouldin Score = 0.6387
# Jaccard Score = 0.0626
# Rand Score = 0.7360
# Folkes e Mallows Score = 0.7661
#
#
# Average Linkage com k=23
# Silouette Score = 0.5141
# Calinski-Harabasz Score = 5658.3701
# Davies-Bouldin Score = 0.6224
# Jaccard Score = 0.0475
# Rand Score = 0.7529
# Folkes e Mallows Score = 0.7791
#
#
# Average Linkage com k=24
# Silouette Score = 0.5171
# Calinski-Harabasz Score = 5863.4133
# Davies-Bouldin Score = 0.6170
# Jaccard Score = 0.0761
# Rand Score = 0.7722
# Folkes e Mallows Score = 0.7944
#
#
# Average Linkage com k=25
# Silouette Score = 0.5140
# Calinski-Harabasz Score = 5633.4158
# Davies-Bouldin Score = 0.6287
# Jaccard Score = 0.0597
# Rand Score = 0.7716
# Folkes e Mallows Score = 0.7937
#
#
# Average Linkage com k=26
# Silouette Score = 0.5273
# Calinski-Harabasz Score = 5871.8351
# Davies-Bouldin Score = 0.5995
# Jaccard Score = 0.0599
# Rand Score = 0.7910
# Folkes e Mallows Score = 0.8092
#
#
# Average Linkage com k=27
# Silouette Score = 0.5290
# Calinski-Harabasz Score = 6140.5899
# Davies-Bouldin Score = 0.5963
# Jaccard Score = 0.0751
# Rand Score = 0.8128
# Folkes e Mallows Score = 0.8275
#
#
# Average Linkage com k=28
# Silouette Score = 0.5426
# Calinski-Harabasz Score = 6467.6627
# Davies-Bouldin Score = 0.5722
# Jaccard Score = 0.0751
# Rand Score = 0.8336
# Folkes e Mallows Score = 0.8451
#
#
# Average Linkage com k=29
# Silouette Score = 0.5520
# Calinski-Harabasz Score = 6889.2812
# Davies-Bouldin Score = 0.5730
# Jaccard Score = 0.1064
# Rand Score = 0.8578
# Folkes e Mallows Score = 0.8661
#
#
# Average Linkage com k=30
# Silouette Score = 0.5550
# Calinski-Harabasz Score = 7359.0556
# Davies-Bouldin Score = 0.5673
# Jaccard Score = 0.0751
# Rand Score = 0.8807
# Folkes e Mallows Score = 0.8863
#
#
# Average Linkage com k=31
# Silouette Score = 0.5623
# Calinski-Harabasz Score = 7960.5455
# Davies-Bouldin Score = 0.5679
# Jaccard Score = 0.0312
# Rand Score = 0.9069
# Folkes e Mallows Score = 0.9104
#
#
# Average Linkage com k=32
# Silouette Score = 0.5666
# Calinski-Harabasz Score = 8683.2619
# Davies-Bouldin Score = 0.5678
# Jaccard Score = 0.0315
# Rand Score = 0.9307
# Folkes e Mallows Score = 0.9329
#
#
# Average Linkage com k=33
# Silouette Score = 0.5628
# Calinski-Harabasz Score = 8427.9920
# Davies-Bouldin Score = 0.5599
# Jaccard Score = 0.0315
# Rand Score = 0.9304
# Folkes e Mallows Score = 0.9326

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.5666 - Best Model: Average Linkage com k=32
# Calinski-Harabasz Score = 8683.2619 - Best Model: Average Linkage com k=32
# Davies-Bouldin Score = 1.1500 - Best Model: Average Linkage com k=2
# Jaccard Score = 0.1064 - Best Model: Average Linkage com k=29
# Rand Score = 0.9307 - Best Model: Average Linkage com k=32
# Folkes e Mallows Score = 0.9329 - Best Model: Average Linkage com k=32

# %% [markdown]
# # <a id="dataset_1_b_III"></a> 1.b.III Dataset D31 - DBSCAN

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}
epsilon_values = list(range(1,10,1))

for k in range(2, 11):

    # #######
    model = DBSCAN(eps=epsilon_values[k-2], min_samples=8)
    model_text = f'DBSCAN com eps={epsilon_values[k-2]} e min_samples=8'
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_
    try:
        silhouette_value = silhouette_score(X, labels)
        if silhouette_value > models_score["Silouette Score"][0]:
            models_score["Silouette Score"] = [silhouette_value, model_text]
        # dunn_value = dunn_index(X, labels, model.cluster_centers_)
        # if dunn_value > models_score["Dunn Score"][0]:
        #     models_score["Dunn Score"] = [dunn_value, model_text]
        ch_value = calinski_harabasz_score(X, labels)
        if ch_value > models_score["Calinski-Harabasz Score"][0]:
            models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
        db_value = davies_bouldin_score(X, labels)
        if db_value > models_score["Davies-Bouldin Score"][0]:
            models_score["Davies-Bouldin Score"] = [db_value, model_text]
        jaccard_value = jaccard_score(Y, labels, average='weighted')
        if jaccard_value > models_score["Jaccard Score"][0]:
            models_score["Jaccard Score"] = [jaccard_value, model_text]
        rand_value = adjusted_rand_score(Y, labels)
        if rand_value > models_score["Rand Score"][0]:
            models_score["Rand Score"] = [rand_value, model_text]
        fm_value = fowlkes_mallows_score(Y, labels)
        if fm_value > models_score["Folkes e Mallows Score"][0]:
            models_score["Folkes e Mallows Score"] = [fm_value, model_text]
    except:
       pass

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
     #   + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# DBSCAN com eps=1 e min_samples=8
# Silouette Score = 0.0808
# Calinski-Harabasz Score = 693.4219
# Davies-Bouldin Score = 9.4449
# Jaccard Score = 0.0000
# Rand Score = 0.1378
# Folkes e Mallows Score = 0.3206
#
#
# DBSCAN com eps=2 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846
#
#
# DBSCAN com eps=3 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846
#
#
# DBSCAN com eps=4 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846
#
#
# DBSCAN com eps=5 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846
# DBSCAN com eps=6 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846
#
#
# DBSCAN com eps=7 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846
#
#
# DBSCAN com eps=8 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846
#
#
# DBSCAN com eps=9 e min_samples=8
# Silouette Score = 0.2304
# Calinski-Harabasz Score = 268.8047
# Davies-Bouldin Score = 0.6332
# Jaccard Score = 0.0000
# Rand Score = 0.0044
# Folkes e Mallows Score = 0.1846

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.2304 - Best Model: DBSCAN com eps=2 e min_samples=8
# Calinski-Harabasz Score = 693.4219 - Best Model: DBSCAN com eps=1 e min_samples=8
# Davies-Bouldin Score = 9.4449 - Best Model: DBSCAN com eps=1 e min_samples=8
# Jaccard Score = 0.0000 - Best Model:
# Rand Score = 0.1378 - Best Model: DBSCAN com eps=1 e min_samples=8
# Folkes e Mallows Score = 0.3206 - Best Model: DBSCAN com eps=1 e min_samples=8

# %% [markdown]
# ---

# %% [markdown]
# # <a id="dataset_1_c"></a> 1.c. Dataset Pathbased

# %%
df = pd.read_csv("pathbased.csv", sep=";", names=["x1","x2","y"])
X = df.drop("y", axis=1)
Y = df["y"]

# %% [markdown]
# # <a id="dataset_1_c_I"></a> 1.c.I. Dataset Pathbased - K-Means

# %%
models_score = {
    "Silouette Score": [0,""],
    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 11):

    # #######
    model = KMeans(n_clusters=k)
    model_text = f"K-Means com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    dunn_value = dunn_index(X, labels, model.cluster_centers_)
    if dunn_value > models_score["Dunn Score"][0]:
        models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# K-Means com k=2
# Silouette Score = 0.5150
# Dunn Score = 0.5330
# Calinski-Harabasz Score = 371.0553
# Davies-Bouldin Score = 0.7523
# Jaccard Score = 0.0939
# Rand Score = 0.3990
# Folkes e Mallows Score = 0.6519
#
#
# K-Means com k=3
# Silouette Score = 0.5406
# Dunn Score = 0.6796
# Calinski-Harabasz Score = 357.8003
# Davies-Bouldin Score = 0.6868
# Jaccard Score = 0.0655
# Rand Score = 0.4642
# Folkes e Mallows Score = 0.6629
#
#
# K-Means com k=4
# Silouette Score = 0.4368
# Dunn Score = 0.3696
# Calinski-Harabasz Score = 318.8801
# Davies-Bouldin Score = 0.8711
# Jaccard Score = 0.2047
# Rand Score = 0.3816
# Folkes e Mallows Score = 0.5801
#
#
# K-Means com k=5
# Silouette Score = 0.3640
# Dunn Score = 0.4370
# Calinski-Harabasz Score = 298.7949
# Davies-Bouldin Score = 0.9606
# Jaccard Score = 0.0632
# Rand Score = 0.4043
# Folkes e Mallows Score = 0.5802
#
#
# K-Means com k=6
# Silouette Score = 0.3871
# Dunn Score = 0.4179
# Calinski-Harabasz Score = 298.3390
# Davies-Bouldin Score = 0.8911
# Jaccard Score = 0.0842
# Rand Score = 0.5308
# Folkes e Mallows Score = 0.6695
#
#
# K-Means com k=7
# Silouette Score = 0.3764
# Dunn Score = 0.4367
# Calinski-Harabasz Score = 309.9774
# Davies-Bouldin Score = 0.8489
# Jaccard Score = 0.0407
# Rand Score = 0.3844
# Folkes e Mallows Score = 0.5551
#
#
# K-Means com k=8
# Silouette Score = 0.3890
# Dunn Score = 0.4785
# Calinski-Harabasz Score = 342.8555
# Davies-Bouldin Score = 0.8096
# Jaccard Score = 0.5264
# Rand Score = 0.4420
# Folkes e Mallows Score = 0.6008
#
#
# K-Means com k=9
# Silouette Score = 0.3882
# Dunn Score = 0.5246
# Calinski-Harabasz Score = 340.2583
# Davies-Bouldin Score = 0.8100
# Jaccard Score = 0.0291
# Rand Score = 0.4093
# Folkes e Mallows Score = 0.5746
#
#
# K-Means com k=10
# Silouette Score = 0.3721
# Dunn Score = 0.3403
# Calinski-Harabasz Score = 340.9124
# Davies-Bouldin Score = 0.7986
# Jaccard Score = 0.0450
# Rand Score = 0.3531
# Folkes e Mallows Score = 0.5282

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.5406 - Best Model: K-Means com k=3
# Dunn Score = 0.6796 - Best Model: K-Means com k=3
# Calinski-Harabasz Score = 371.0553 - Best Model: K-Means com k=2
# Davies-Bouldin Score = 0.9606 - Best Model: K-Means com k=5
# Jaccard Score = 0.5264 - Best Model: K-Means com k=8
# Rand Score = 0.5308 - Best Model: K-Means com k=6
# Folkes e Mallows Score = 0.6695 - Best Model: K-Means com k=6

# %% [markdown]
# # <a id="dataset_1_c_II"></a> 1.c.II. Dataset Pathbased - Average Linkage

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 11):

    # #######
    model = AgglomerativeClustering(n_clusters=k, linkage='average')
    model_text = f"Average Linkage com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    # dunn_value = dunn_index(X, labels, model.cluster_centers_)
    # if dunn_value > models_score["Dunn Score"][0]:
    #     models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        # + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# Average Linkage com k=2
# Silouette Score = 0.4911
# Calinski-Harabasz Score = 316.9184
# Davies-Bouldin Score = 0.8007
# Jaccard Score = 0.0809
# Rand Score = 0.3947
# Folkes e Mallows Score = 0.6501
#
#
# Average Linkage com k=3
# Silouette Score = 0.5386
# Calinski-Harabasz Score = 353.9570
# Davies-Bouldin Score = 0.6309
# Jaccard Score = 0.3352
# Rand Score = 0.4436
# Folkes e Mallows Score = 0.6526
#
#
# Average Linkage com k=4
# Silouette Score = 0.4756
# Calinski-Harabasz Score = 286.4206
# Davies-Bouldin Score = 0.6237
# Jaccard Score = 0.2963
# Rand Score = 0.4629
# Folkes e Mallows Score = 0.6555
#
#
# Average Linkage com k=5
# Silouette Score = 0.4227
# Calinski-Harabasz Score = 241.5164
# Davies-Bouldin Score = 0.5724
# Jaccard Score = 0.3018
# Rand Score = 0.4515
# Folkes e Mallows Score = 0.6468
#
#
# Average Linkage com k=6
# Silouette Score = 0.3986
# Calinski-Harabasz Score = 232.0410
# Davies-Bouldin Score = 0.6029
# Jaccard Score = 0.0682
# Rand Score = 0.4851
# Folkes e Mallows Score = 0.6594
#
#
# Average Linkage com k=7
# Silouette Score = 0.3560
# Calinski-Harabasz Score = 248.8595
# Davies-Bouldin Score = 0.7052
# Jaccard Score = 0.0682
# Rand Score = 0.5167
# Folkes e Mallows Score = 0.6675
#
#
# Average Linkage com k=8
# Silouette Score = 0.3783
# Calinski-Harabasz Score = 262.2384
# Davies-Bouldin Score = 0.6831
# Jaccard Score = 0.0806
# Rand Score = 0.5818
# Folkes e Mallows Score = 0.7088
#
#
# Average Linkage com k=9
# Silouette Score = 0.3948
# Calinski-Harabasz Score = 291.7173
# Davies-Bouldin Score = 0.7114
# Jaccard Score = 0.0167
# Rand Score = 0.6691
# Folkes e Mallows Score = 0.7746
#
#
# Average Linkage com k=10
# Silouette Score = 0.4011
# Calinski-Harabasz Score = 280.8453
# Davies-Bouldin Score = 0.6860
# Jaccard Score = 0.0027
# Rand Score = 0.6631
# Folkes e Mallows Score = 0.7704

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.5386 - Best Model: Average Linkage com k=3
# Calinski-Harabasz Score = 353.9570 - Best Model: Average Linkage com k=3
# Davies-Bouldin Score = 0.8007 - Best Model: Average Linkage com k=2
# Jaccard Score = 0.3352 - Best Model: Average Linkage com k=3
# Rand Score = 0.6691 - Best Model: Average Linkage com k=9
# Folkes e Mallows Score = 0.7746 - Best Model: Average Linkage com k=9

# %% [markdown]
# # <a id="dataset_1_c_III"></a> 1.c.III Dataset Pathbased - DBSCAN

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}
epsilon_values = [1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3]

for k in range(2, 11):

    # #######
    model = DBSCAN(eps=epsilon_values[k-2], min_samples=8)
    model_text = f'DBSCAN com eps={epsilon_values[k-2]} e min_samples=8'
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_
    try:
        silhouette_value = silhouette_score(X, labels)
        if silhouette_value > models_score["Silouette Score"][0]:
            models_score["Silouette Score"] = [silhouette_value, model_text]
        # dunn_value = dunn_index(X, labels, model.cluster_centers_)
        # if dunn_value > models_score["Dunn Score"][0]:
        #     models_score["Dunn Score"] = [dunn_value, model_text]
        ch_value = calinski_harabasz_score(X, labels)
        if ch_value > models_score["Calinski-Harabasz Score"][0]:
            models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
        db_value = davies_bouldin_score(X, labels)
        if db_value > models_score["Davies-Bouldin Score"][0]:
            models_score["Davies-Bouldin Score"] = [db_value, model_text]
        jaccard_value = jaccard_score(Y, labels, average='weighted')
        if jaccard_value > models_score["Jaccard Score"][0]:
            models_score["Jaccard Score"] = [jaccard_value, model_text]
        rand_value = adjusted_rand_score(Y, labels)
        if rand_value > models_score["Rand Score"][0]:
            models_score["Rand Score"] = [rand_value, model_text]
        fm_value = fowlkes_mallows_score(Y, labels)
        if fm_value > models_score["Folkes e Mallows Score"][0]:
            models_score["Folkes e Mallows Score"] = [fm_value, model_text]
    except:
       pass

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
     #   + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# DBSCAN com eps=1 e min_samples=8
# Silouette Score = -0.3911
# Calinski-Harabasz Score = 7.4666
# Davies-Bouldin Score = 1.5807
# Jaccard Score = 0.0433
# Rand Score = 0.0423
# Folkes e Mallows Score = 0.5228
#
#
# DBSCAN com eps=1.25 e min_samples=8
# Silouette Score = -0.0767
# Calinski-Harabasz Score = 21.5301
# Davies-Bouldin Score = 1.9202
# Jaccard Score = 0.2500
# Rand Score = 0.3767
# Folkes e Mallows Score = 0.6226
#
#
# DBSCAN com eps=1.5 e min_samples=8
# Silouette Score = 0.1341
# Calinski-Harabasz Score = 38.6580
# Davies-Bouldin Score = 2.2988
# Jaccard Score = 0.0000
# Rand Score = 0.6311
# Folkes e Mallows Score = 0.7619
#
#
# DBSCAN com eps=1.75 e min_samples=8
# Silouette Score = 0.1636
# Calinski-Harabasz Score = 40.9267
# Davies-Bouldin Score = 2.0803
# Jaccard Score = 0.3038
# Rand Score = 0.7854
# Folkes e Mallows Score = 0.8556
#
#
# DBSCAN com eps=2 e min_samples=8
# Silouette Score = 0.1682
# Calinski-Harabasz Score = 47.8750
# Davies-Bouldin Score = 1.6406
# Jaccard Score = 0.3370
# Rand Score = 0.7873
# Folkes e Mallows Score = 0.8554
#
#
# DBSCAN com eps=2.25 e min_samples=8
# Silouette Score = 0.2948
# Calinski-Harabasz Score = 75.4146
# Davies-Bouldin Score = 2.0070
# Jaccard Score = 0.3551
# Rand Score = 0.7067
# Folkes e Mallows Score = 0.8016
#
#
# DBSCAN com eps=2.5 e min_samples=8
# Silouette Score = 0.1283
# Calinski-Harabasz Score = 16.6514
# Davies-Bouldin Score = 4.5474
# Jaccard Score = 0.0333
# Rand Score = 0.1232
# Folkes e Mallows Score = 0.5303
#
#
# DBSCAN com eps=2.75 e min_samples=8
# Silouette Score = 0.1356
# Calinski-Harabasz Score = 17.3226
# Davies-Bouldin Score = 2.6838
# Jaccard Score = 0.0400
# Rand Score = 0.0078
# Folkes e Mallows Score = 0.5209
#
#
# DBSCAN com eps=3 e min_samples=8
# Silouette Score = -0.0198
# Calinski-Harabasz Score = 1.0341
# Davies-Bouldin Score = 0.9080
# Jaccard Score = 0.0000
# Rand Score = 0.0002
# Folkes e Mallows Score = 0.5752

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.2948 - Best Model: DBSCAN com eps=2.25 e min_samples=8
# Calinski-Harabasz Score = 75.4146 - Best Model: DBSCAN com eps=2.25 e min_samples=8
# Davies-Bouldin Score = 4.5474 - Best Model: DBSCAN com eps=2.5 e min_samples=8
# Jaccard Score = 0.3551 - Best Model: DBSCAN com eps=2.25 e min_samples=8
# Rand Score = 0.7873 - Best Model: DBSCAN com eps=2 e min_samples=8
# Folkes e Mallows Score = 0.8556 - Best Model: DBSCAN com eps=1.75 e min_samples=8

# %% [markdown]
# ---

# %% [markdown]
# # <a id="dataset_1_d"></a> 1.d. Dataset Flame

# %%
df = pd.read_csv("flame.csv", sep=";", names=["x1","x2","y"])
X = df.drop("y", axis=1)
Y = df["y"]

# %% [markdown]
# # <a id="dataset_1_d_I"></a> 1.d.I. Dataset Flame - K-Means

# %%
models_score = {
    "Silouette Score": [0,""],
    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 11):

    # #######
    model = KMeans(n_clusters=k)
    model_text = f"K-Means com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    dunn_value = dunn_index(X, labels, model.cluster_centers_)
    if dunn_value > models_score["Dunn Score"][0]:
        models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# K-Means com k=2
# Silouette Score = 0.3768
# Dunn Score = 0.4180
# Calinski-Harabasz Score = 154.2215
# Davies-Bouldin Score = 1.1219
# Jaccard Score = 0.2559
# Rand Score = 0.4998
# Folkes e Mallows Score = 0.7586
#
#
# K-Means com k=3
# Silouette Score = 0.4106
# Dunn Score = 0.5508
# Calinski-Harabasz Score = 200.5064
# Davies-Bouldin Score = 0.8303
# Jaccard Score = 0.0123
# Rand Score = 0.5261
# Folkes e Mallows Score = 0.7415
#
#
# K-Means com k=4
# Silouette Score = 0.4427
# Dunn Score = 0.5951
# Calinski-Harabasz Score = 258.0822
# Davies-Bouldin Score = 0.6926
# Jaccard Score = 0.3009
# Rand Score = 0.4316
# Folkes e Mallows Score = 0.6728
#
#
# K-Means com k=5
# Silouette Score = 0.3984
# Dunn Score = 0.3644
# Calinski-Harabasz Score = 229.7607
# Davies-Bouldin Score = 0.8786
# Jaccard Score = 0.4132
# Rand Score = 0.3083
# Folkes e Mallows Score = 0.5751
#
#
# K-Means com k=6
# Silouette Score = 0.3688
# Dunn Score = 0.3807
# Calinski-Harabasz Score = 240.4068
# Davies-Bouldin Score = 0.9184
# Jaccard Score = 0.1167
# Rand Score = 0.2863
# Folkes e Mallows Score = 0.5501
#
#
# K-Means com k=7
# Silouette Score = 0.3840
# Dunn Score = 0.5411
# Calinski-Harabasz Score = 245.0047
# Davies-Bouldin Score = 0.8032
# Jaccard Score = 0.2614
# Rand Score = 0.2435
# Folkes e Mallows Score = 0.5084
#
#
# K-Means com k=8
# Silouette Score = 0.3794
# Dunn Score = 0.5118
# Calinski-Harabasz Score = 259.9930
# Davies-Bouldin Score = 0.7951
# Jaccard Score = 0.1292
# Rand Score = 0.2095
# Folkes e Mallows Score = 0.4726
#
#
# K-Means com k=9
# Silouette Score = 0.3586
# Dunn Score = 0.4204
# Calinski-Harabasz Score = 256.7855
# Davies-Bouldin Score = 0.8560
# Jaccard Score = 0.0000
# Rand Score = 0.1778
# Folkes e Mallows Score = 0.4360
#
#
# K-Means com k=10
# Silouette Score = 0.3417
# Dunn Score = 0.3666
# Calinski-Harabasz Score = 249.3878
# Davies-Bouldin Score = 0.8759
# Jaccard Score = 0.0917
# Rand Score = 0.1547
# Folkes e Mallows Score = 0.4076

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.4427 - Best Model: K-Means com k=4
# Dunn Score = 0.5951 - Best Model: K-Means com k=4
# Calinski-Harabasz Score = 259.9930 - Best Model: K-Means com k=8
# Davies-Bouldin Score = 1.1219 - Best Model: K-Means com k=2
# Jaccard Score = 0.4132 - Best Model: K-Means com k=5
# Rand Score = 0.5261 - Best Model: K-Means com k=3
# Folkes e Mallows Score = 0.7586 - Best Model: K-Means com k=2

# %% [markdown]
# # <a id="dataset_1_d_II"></a> 1.d.II. Dataset Flame - Average Linkage

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}

for k in range(2, 11):

    # #######
    model = AgglomerativeClustering(n_clusters=k, linkage='average')
    model_text = f"Average Linkage com k={k}"
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_

    silhouette_value = silhouette_score(X, labels)
    if silhouette_value > models_score["Silouette Score"][0]:
        models_score["Silouette Score"] = [silhouette_value, model_text]
    # dunn_value = dunn_index(X, labels, model.cluster_centers_)
    # if dunn_value > models_score["Dunn Score"][0]:
    #     models_score["Dunn Score"] = [dunn_value, model_text]
    ch_value = calinski_harabasz_score(X, labels)
    if ch_value > models_score["Calinski-Harabasz Score"][0]:
        models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
    db_value = davies_bouldin_score(X, labels)
    if db_value > models_score["Davies-Bouldin Score"][0]:
        models_score["Davies-Bouldin Score"] = [db_value, model_text]
    jaccard_value = jaccard_score(Y, labels, average='weighted')
    if jaccard_value > models_score["Jaccard Score"][0]:
        models_score["Jaccard Score"] = [jaccard_value, model_text]
    rand_value = adjusted_rand_score(Y, labels)
    if rand_value > models_score["Rand Score"][0]:
        models_score["Rand Score"] = [rand_value, model_text]
    fm_value = fowlkes_mallows_score(Y, labels)
    if fm_value > models_score["Folkes e Mallows Score"][0]:
        models_score["Folkes e Mallows Score"] = [fm_value, model_text]

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
        # + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# Average Linkage com k=2
# Silouette Score = 0.3723
# Calinski-Harabasz Score = 151.6404
# Davies-Bouldin Score = 1.1325
# Jaccard Score = 0.0000
# Rand Score = 0.4422
# Folkes e Mallows Score = 0.7311
#
#
# Average Linkage com k=3
# Silouette Score = 0.3973
# Calinski-Harabasz Score = 172.4504
# Davies-Bouldin Score = 0.8181
# Jaccard Score = 0.5292
# Rand Score = 0.6902
# Folkes e Mallows Score = 0.8402
#
#
# Average Linkage com k=4
# Silouette Score = 0.4385
# Calinski-Harabasz Score = 245.5487
# Davies-Bouldin Score = 0.6719
# Jaccard Score = 0.1667
# Rand Score = 0.5043
# Folkes e Mallows Score = 0.7231
#
#
# Average Linkage com k=5
# Silouette Score = 0.3803
# Calinski-Harabasz Score = 215.2768
# Davies-Bouldin Score = 0.7824
# Jaccard Score = 0.4792
# Rand Score = 0.4459
# Folkes e Mallows Score = 0.6815
#
#
# Average Linkage com k=6
# Silouette Score = 0.3560
# Calinski-Harabasz Score = 175.6411
# Davies-Bouldin Score = 0.7434
# Jaccard Score = 0.1667
# Rand Score = 0.4446
# Folkes e Mallows Score = 0.6805
#
#
# Average Linkage com k=7
# Silouette Score = 0.3845
# Calinski-Harabasz Score = 183.0316
# Davies-Bouldin Score = 0.7345
# Jaccard Score = 0.1667
# Rand Score = 0.3545
# Folkes e Mallows Score = 0.6097
#
#
# Average Linkage com k=8
# Silouette Score = 0.3403
# Calinski-Harabasz Score = 197.8264
# Davies-Bouldin Score = 0.8379
# Jaccard Score = 0.1667
# Rand Score = 0.2633
# Folkes e Mallows Score = 0.5273
#
#
# Average Linkage com k=9
# Silouette Score = 0.3273
# Calinski-Harabasz Score = 202.5565
# Davies-Bouldin Score = 0.8300
# Jaccard Score = 0.0000
# Rand Score = 0.2388
# Folkes e Mallows Score = 0.5026
#
#
# Average Linkage com k=10
# Silouette Score = 0.2904
# Calinski-Harabasz Score = 192.8325
# Davies-Bouldin Score = 0.7924
# Jaccard Score = 0.1625
# Rand Score = 0.2278
# Folkes e Mallows Score = 0.4911

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.4385 - Best Model: Average Linkage com k=4
# Calinski-Harabasz Score = 245.5487 - Best Model: Average Linkage com k=4
# Davies-Bouldin Score = 1.1325 - Best Model: Average Linkage com k=2
# Jaccard Score = 0.5292 - Best Model: Average Linkage com k=3
# Rand Score = 0.6902 - Best Model: Average Linkage com k=3
# Folkes e Mallows Score = 0.8402 - Best Model: Average Linkage com k=3

# %% [markdown]
# # <a id="dataset_1_d_III"></a> 1.d.III Dataset Flame - DBSCAN

# %%
models_score = {
    "Silouette Score": [0,""],
#    "Dunn Score": [0,""],
    "Calinski-Harabasz Score": [0,""],
    "Davies-Bouldin Score": [0,""],
    "Jaccard Score": [0,""],
    "Rand Score": [0,""],
    "Folkes e Mallows Score": [0,""],
}
epsilon_values = [0.3, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]

for k in range(2, 11):

    # #######
    model = DBSCAN(eps=epsilon_values[k-2], min_samples=8)
    model_text = f'DBSCAN com eps={epsilon_values[k-2]} e min_samples=8'
    # #######

    clusters = model.fit_predict(X)
    labels = model.labels_
    try:
        silhouette_value = silhouette_score(X, labels)
        if silhouette_value > models_score["Silouette Score"][0]:
            models_score["Silouette Score"] = [silhouette_value, model_text]
        # dunn_value = dunn_index(X, labels, model.cluster_centers_)
        # if dunn_value > models_score["Dunn Score"][0]:
        #     models_score["Dunn Score"] = [dunn_value, model_text]
        ch_value = calinski_harabasz_score(X, labels)
        if ch_value > models_score["Calinski-Harabasz Score"][0]:
            models_score["Calinski-Harabasz Score"] = [ch_value, model_text]
        db_value = davies_bouldin_score(X, labels)
        if db_value > models_score["Davies-Bouldin Score"][0]:
            models_score["Davies-Bouldin Score"] = [db_value, model_text]
        jaccard_value = jaccard_score(Y, labels, average='weighted')
        if jaccard_value > models_score["Jaccard Score"][0]:
            models_score["Jaccard Score"] = [jaccard_value, model_text]
        rand_value = adjusted_rand_score(Y, labels)
        if rand_value > models_score["Rand Score"][0]:
            models_score["Rand Score"] = [rand_value, model_text]
        fm_value = fowlkes_mallows_score(Y, labels)
        if fm_value > models_score["Folkes e Mallows Score"][0]:
            models_score["Folkes e Mallows Score"] = [fm_value, model_text]
    except:
       pass

    text = (
        # #######
        model_text + "\n"
        # #######
        + f"Silouette Score = {silhouette_value:.4f}" + "\n"
     #   + f"Dunn Score = {dunn_value:.4f}" + "\n"
        + f"Calinski-Harabasz Score = {ch_value:.4f}" + "\n"
        + f"Davies-Bouldin Score = {db_value:.4f}" + "\n"
        + f"Jaccard Score = {jaccard_value:.4f}" + "\n"
        + f"Rand Score = {rand_value:.4f}" + "\n"
        + f"Folkes e Mallows Score = {fm_value:.4f}" + "\n\n")
    print(text)
# Out:
# DBSCAN com eps=0.3 e min_samples=8
# Silouette Score = 0.2904
# Calinski-Harabasz Score = 192.8325
# Davies-Bouldin Score = 0.7924
# Jaccard Score = 0.1625
# Rand Score = 0.2278
# Folkes e Mallows Score = 0.4911
#
#
# DBSCAN com eps=0.5 e min_samples=8
# Silouette Score = 0.2904
# Calinski-Harabasz Score = 192.8325
# Davies-Bouldin Score = 0.7924
# Jaccard Score = 0.1625
# Rand Score = 0.2278
# Folkes e Mallows Score = 0.4911
#
#
# DBSCAN com eps=1.0 e min_samples=8
# Silouette Score = 0.0327
# Calinski-Harabasz Score = 37.5791
# Davies-Bouldin Score = 2.3819
# Jaccard Score = 0.2292
# Rand Score = 0.1756
# Folkes e Mallows Score = 0.4688
#
#
# DBSCAN com eps=1.5 e min_samples=8
# Silouette Score = 0.2952
# Calinski-Harabasz Score = 6.8944
# Davies-Bouldin Score = 0.5798
# Jaccard Score = 0.0000
# Rand Score = 0.0128
# Folkes e Mallows Score = 0.7300
#
#
# DBSCAN com eps=2.0 e min_samples=8
# Silouette Score = 0.2952
# Calinski-Harabasz Score = 6.8944
# Davies-Bouldin Score = 0.5798
# Jaccard Score = 0.0000
# Rand Score = 0.0128
# Folkes e Mallows Score = 0.7300
#
#
# DBSCAN com eps=2.5 e min_samples=8
# Silouette Score = 0.2952
# Calinski-Harabasz Score = 6.8944
# Davies-Bouldin Score = 0.5798
# Jaccard Score = 0.0000
# Rand Score = 0.0128
# Folkes e Mallows Score = 0.7300
#
#
# DBSCAN com eps=3.0 e min_samples=8
# Silouette Score = 0.2952
# Calinski-Harabasz Score = 6.8944
# Davies-Bouldin Score = 0.5798
# Jaccard Score = 0.0000
# Rand Score = 0.0128
# Folkes e Mallows Score = 0.7300
#
#
# DBSCAN com eps=3.5 e min_samples=8
# Silouette Score = 0.2952
# Calinski-Harabasz Score = 6.8944
# Davies-Bouldin Score = 0.5798
# Jaccard Score = 0.0000
# Rand Score = 0.0128
# Folkes e Mallows Score = 0.7300
#
#
# DBSCAN com eps=4.0 e min_samples=8
# Silouette Score = 0.2952
# Calinski-Harabasz Score = 6.8944
# Davies-Bouldin Score = 0.5798
# Jaccard Score = 0.0000
# Rand Score = 0.0128
# Folkes e Mallows Score = 0.7300

# %%
for algoritm, score in models_score.items():
    print(f"{algoritm} = {score[0]:.4f} - Best Model: {score[1]}")
# Out:
# Silouette Score = 0.2952 - Best Model: DBSCAN com eps=1.5 e min_samples=8
# Calinski-Harabasz Score = 37.5791 - Best Model: DBSCAN com eps=1.0 e min_samples=8
# Davies-Bouldin Score = 2.3819 - Best Model: DBSCAN com eps=1.0 e min_samples=8
# Jaccard Score = 0.2292 - Best Model: DBSCAN com eps=1.0 e min_samples=8
# Rand Score = 0.1756 - Best Model: DBSCAN com eps=1.0 e min_samples=8
# Folkes e Mallows Score = 0.7300 - Best Model: DBSCAN com eps=1.5 e min_samples=8

# %% [markdown]
# ---
